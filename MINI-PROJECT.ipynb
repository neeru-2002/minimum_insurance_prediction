# %% [markdown]
# In \[36\]:
#
#     import pandas as pd
#     import matplotlib.pyplot as plt
#     import numpy as np
#     import seaborn as sns
#     from sklearn.model_selection import cross_val_score
#     %matplotlib inline
#
# In \[3\]:
#
#     df=pd.read_csv("C:/Users/megha/Desktop/MINI_PROJECT/Medicalpremium.csv")
#     df.head()
#
# Out\[3\]:
#
# |     | Age | Diabetes | BloodPressureProblems | AnyTransplants | AnyChronicDiseases | Height | Weight | KnownAllergies | HistoryOfCancerInFamily | NumberOfMajorSurgeries | PremiumPrice |
# |-----|-----|----------|-----------------------|----------------|--------------------|--------|--------|----------------|-------------------------|------------------------|--------------|
# | 0   | 45  | 0        | 0                     | 0              | 0                  | 155    | 57     | 0              | 0                       | 0                      | 100000       |
# | 1   | 60  | 1        | 0                     | 0              | 0                  | 180    | 73     | 0              | 0                       | 0                      | 116000       |
# | 2   | 36  | 1        | 1                     | 0              | 0                  | 158    | 59     | 0              | 0                       | 1                      | 92000        |
# | 3   | 52  | 1        | 1                     | 0              | 1                  | 183    | 93     | 0              | 0                       | 2                      | 112000       |
# | 4   | 38  | 0        | 0                     | 0              | 1                  | 166    | 88     | 0              | 0                       | 1                      | 92000        |
#
# In \[4\]:
#
#     df.describe()
#
# Out\[4\]:
#
# |       | Age        | Diabetes   | BloodPressureProblems | AnyTransplants | AnyChronicDiseases | Height     | Weight     | KnownAllergies | HistoryOfCancerInFamily | NumberOfMajorSurgeries | PremiumPrice  |
# |-------|------------|------------|-----------------------|----------------|--------------------|------------|------------|----------------|-------------------------|------------------------|---------------|
# | count | 986.000000 | 986.000000 | 986.000000            | 986.000000     | 986.000000         | 986.000000 | 986.000000 | 986.000000     | 986.000000              | 986.000000             | 986.000000    |
# | mean  | 41.745436  | 0.419878   | 0.468560              | 0.055781       | 0.180527           | 168.182556 | 76.950304  | 0.215010       | 0.117647                | 0.667343               | 97346.855984  |
# | std   | 13.963371  | 0.493789   | 0.499264              | 0.229615       | 0.384821           | 10.098155  | 14.265096  | 0.411038       | 0.322353                | 0.749205               | 24992.737529  |
# | min   | 18.000000  | 0.000000   | 0.000000              | 0.000000       | 0.000000           | 145.000000 | 51.000000  | 0.000000       | 0.000000                | 0.000000               | 60000.000000  |
# | 25%   | 30.000000  | 0.000000   | 0.000000              | 0.000000       | 0.000000           | 161.000000 | 67.000000  | 0.000000       | 0.000000                | 0.000000               | 84000.000000  |
# | 50%   | 42.000000  | 0.000000   | 0.000000              | 0.000000       | 0.000000           | 168.000000 | 75.000000  | 0.000000       | 0.000000                | 1.000000               | 92000.000000  |
# | 75%   | 53.000000  | 1.000000   | 1.000000              | 0.000000       | 0.000000           | 176.000000 | 87.000000  | 0.000000       | 0.000000                | 1.000000               | 112000.000000 |
# | max   | 66.000000  | 1.000000   | 1.000000              | 1.000000       | 1.000000           | 188.000000 | 132.000000 | 1.000000       | 1.000000                | 3.000000               | 160000.000000 |
#
# In \[5\]:
#
#     df.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 986 entries, 0 to 985
#     Data columns (total 11 columns):
#      #   Column                   Non-Null Count  Dtype
#     ---  ------                   --------------  -----
#      0   Age                      986 non-null    int64
#      1   Diabetes                 986 non-null    int64
#      2   BloodPressureProblems    986 non-null    int64
#      3   AnyTransplants           986 non-null    int64
#      4   AnyChronicDiseases       986 non-null    int64
#      5   Height                   986 non-null    int64
#      6   Weight                   986 non-null    int64
#      7   KnownAllergies           986 non-null    int64
#      8   HistoryOfCancerInFamily  986 non-null    int64
#      9   NumberOfMajorSurgeries   986 non-null    int64
#      10  PremiumPrice             986 non-null    int64
#     dtypes: int64(11)
#     memory usage: 84.9 KB
#
# In \[6\]:
#
#     s=dict(df.isnull().sum())
#     print(s)
#
#     {'Age': 0, 'Diabetes': 0, 'BloodPressureProblems': 0, 'AnyTransplants': 0, 'AnyChronicDiseases': 0, 'Height': 0, 'Weight': 0, 'KnownAllergies': 0, 'HistoryOfCancerInFamily': 0, 'NumberOfMajorSurgeries': 0, 'PremiumPrice': 0}
#
# In \[7\]:
#
#     corr = df.corr()
#     fig,ax = plt.subplots(figsize=(10,10))
#     sns.heatmap(corr,annot=True)
#
# Out\[7\]:
#
#     <matplotlib.axes._subplots.AxesSubplot at 0x1d68604ed90>
#
# ![](data:image/png;base64,...%0A)
#
# In \[8\]:
#
#     df.columns
#
# Out\[8\]:
#
#     Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#            'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#            'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#           dtype='object')
#
# In \[9\]:
#
#     sns.scatterplot('Age','PremiumPrice', hue='Age', data=df)
#
# Out\[9\]:
#
#     <matplotlib.axes._subplots.AxesSubplot at 0x1d686b81c40>
#
# ![](data:image/png;base64,...%0A)
#
# In \[11\]:
#
#     sns.scatterplot('Age','PremiumPrice', hue='Diabetes', data=df)
#
# Out\[11\]:
#
#     <matplotlib.axes._subplots.AxesSubplot at 0x1d686e6a910>
#
# ![](data:image/png;base64,...%0A)
#
# In \[12\]:
#
#     sns.scatterplot('Weight','Height',hue='PremiumPrice', data=df)
#
# Out\[12\]:
#
#     <matplotlib.axes._subplots.AxesSubplot at 0x1d686df77c0>
#
# ![](data:image/png;base64,...%0A)
#
# In \[14\]:
#
#     from sklearn.pipeline import Pipeline, make_pipeline
#     from sklearn.compose import ColumnTransformer, make_column_transformer
#     from sklearn.preprocessing import StandardScaler
#     numeric_features = ['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#            'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#            'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries']
#     numeric_transformer = Pipeline(steps=[('scaler', StandardScaler())])
#
#     preprocessor = ColumnTransformer(
#         transformers=[('num', numeric_transformer, numeric_features)])
#
# In \[15\]:
#
#     from sklearn.model_selection import train_test_split
#     x = df.drop(columns = 'PremiumPrice')
#     y = df['PremiumPrice']
#     x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=10)
#
# In \[73\]:
#
#     !pip install lightgbm
#
#     Requirement already satisfied: lightgbm in c:\users\megha\anaconda3\lib\site-packages (3.3.2)
#     Requirement already satisfied: scipy in c:\users\megha\anaconda3\lib\site-packages (from lightgbm) (1.5.0)
#     Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\megha\anaconda3\lib\site-packages (from lightgbm) (0.23.1)
#     Requirement already satisfied: wheel in c:\users\megha\anaconda3\lib\site-packages (from lightgbm) (0.34.2)
#     Requirement already satisfied: numpy in c:\users\megha\anaconda3\lib\site-packages (from lightgbm) (1.18.5)
#     Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\megha\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
#     Requirement already satisfied: joblib>=0.11 in c:\users\megha\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (0.16.0)
#
# In \[105\]:
#
#     !pip install xgboost
#
#     Collecting xgboost
#       Downloading xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
#     Requirement already satisfied: numpy in c:\users\megha\anaconda3\lib\site-packages (from xgboost) (1.18.5)
#     Requirement already satisfied: scipy in c:\users\megha\anaconda3\lib\site-packages (from xgboost) (1.5.0)
#     Installing collected packages: xgboost
#     Successfully installed xgboost-1.6.1
#     Collecting xgboost
#       Downloading xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
#     Requirement already satisfied (use --upgrade to upgrade): xgboost from https://files.pythonhosted.org/packages/66/88/11cbea9c7a4ebae26c16ef20c14bfca3fa5aded4b0de27ccd8482429e7bf/xgboost-1.6.1-py3-none-win_amd64.whl#sha256=3adcb7e4ccf774d5e0128c01e5c381303c3799910ab0f2e996160fe3cd23b7fc in c:\users\megha\anaconda3\lib\site-packages
#     Requirement already satisfied: scipy in c:\users\megha\anaconda3\lib\site-packages (from xgboost) (1.5.0)
#     Requirement already satisfied: numpy in c:\users\megha\anaconda3\lib\site-packages (from xgboost) (1.18.5)
#
# In \[16\]:
#
#     from sklearn.linear_model import LinearRegression
#     from sklearn.tree import DecisionTreeRegressor
#     from sklearn.neighbors import KNeighborsRegressor
#     from sklearn.ensemble import RandomForestRegressor
#     from sklearn.ensemble import GradientBoostingRegressor
#     from sklearn import preprocessing
#     from lightgbm import LGBMRegressor
#     from xgboost import XGBRegressor
#
# In \[17\]:
#
#     pipeline_lr = Pipeline(steps=[('preprocessor', preprocessor), ('linear_regressor', LinearRegression())])
#     pipeline_dt = Pipeline(steps=[('preprocessor',preprocessor),('decision_tree_regressor', DecisionTreeRegressor())])
#     pipeline_knn = Pipeline(steps=[('preprocessor',preprocessor),('knn',KNeighborsRegressor(n_neighbors=9))])
#     pipeline_rf = Pipeline(steps=[('preprocessor',preprocessor),('random_forest',RandomForestRegressor())])
#     pipeline_gb = Pipeline(steps=[('preprocessor',preprocessor),('gradient_boosting', GradientBoostingRegressor())])
#     pipeline_gbm = Pipeline(steps=[('preprocessor',preprocessor),('light_gradient_boosting', LGBMRegressor())])
#     pipeline_xgb = Pipeline(steps=[('preprocessor',preprocessor),('x_gradient_boosting', XGBRegressor())])
#
# In \[18\]:
#
#     pipelines = [pipeline_dt,pipeline_gb,pipeline_knn,pipeline_lr,pipeline_rf,pipeline_gbm,pipeline_xgb]
#
# In \[19\]:
#
#     best_accuracy = 0.0
#     best_regressor = 0
#     best_pipeline = ''
#
# In \[20\]:
#
#     pipe_dict = {0:'Linear Regression',1:'Decision Tree',2:'KNN',3:'Random forest',4:'Gradient boosting',5:'LGBMRegressor',6:'XGBRegressor'}
#
# In \[21\]:
#
#     for pipe in pipelines:
#         pipe.fit(x_train,y_train)
#
# In \[22\]:
#
#     from sklearn.metrics import r2_score, accuracy_score, confusion_matrix,mean_squared_error,mean_absolute_error,classification_report
#
# In \[23\]:
#
#     pred_lr = pipeline_lr.predict(x_test)
#     linear_reg_mse = mean_squared_error(y_test, pred_lr)
#     linear_reg_rmse = mean_squared_error(y_test, pred_lr, squared=False)
#     linear_reg_r2_score = r2_score(y_test, pred_lr)
#
#     print("The Mean Squared Error using Linear Regression :{}".format(linear_reg_mse))
#     print(('The Root Mean Squared Error using Linear Regression :{}'.format(linear_reg_rmse)))
#     print(('The r2_score using Linear Regression :{}'.format(linear_reg_r2_score)))
#
#     The Mean Squared Error using Linear Regression :232024495.59005967
#     The Root Mean Squared Error using Linear Regression :15232.350297641518
#     The r2_score using Linear Regression :0.631930333988769
#
# In \[24\]:
#
#     pred_dt = pipeline_dt.predict(x_test)
#     decision_tree_mse = mean_squared_error(y_test, pred_dt)
#     decision_tree_rmse = mean_squared_error(y_test, pred_dt, squared=False)
#     decision_tree_r2_score = r2_score(y_test, pred_dt)
#
#     print("The Mean Squared Error using Decision Tree Regressor : {}".format(decision_tree_mse))
#     print("The Root Mean Squared Error using Decision Tree Regressor : {}".format(decision_tree_rmse))
#     print("The r2_score using Decision Tree Regressor : {}".format(decision_tree_r2_score))
#
#     The Mean Squared Error using Decision Tree Regressor : 193036437.24696356
#     The Root Mean Squared Error using Decision Tree Regressor : 13893.755332773193
#     The r2_score using Decision Tree Regressor : 0.6937786383079987
#
# In \[25\]:
#
#     pred_knn = pipeline_knn.predict(x_test)
#     knn_mse = mean_squared_error(y_test, pred_knn)
#     knn_rmse = mean_squared_error(y_test, pred_knn, squared=False)
#     knn_r2_score = r2_score(y_test, pred_knn)
#
#     print("The mean squared error using KNN is {}".format(knn_mse))
#     print("The root mean squared error using KNN is {}".format(knn_rmse))
#     print("The r2_score using KNN is {}".format(knn_r2_score))
#
#     The mean squared error using KNN is 287668116.1593442
#     The root mean squared error using KNN is 16960.781708380786
#     The r2_score using KNN is 0.543660650279263
#
# In \[26\]:
#
#     pred_rf = pipeline_rf.predict(x_test)
#     random_forest_mse = mean_squared_error(y_test, pred_rf)
#     random_forest_rmse = mean_squared_error(y_test, pred_rf, squared=False)
#     random_forest_r2_score = r2_score(y_test, pred_rf)
#
#     print("The Mean Squared Error using Random Forest Regressor : {}".format(random_forest_mse))
#     print("The Root Mean Squared Error using Random Forest Regressor : {}".format(random_forest_rmse))
#     print("The r2_score Error using Random Forest Regressor : {}".format(random_forest_r2_score))
#
#     The Mean Squared Error using Random Forest Regressor : 94170850.20242915
#     The Root Mean Squared Error using Random Forest Regressor : 9704.166641315942
#     The r2_score Error using Random Forest Regressor : 0.8506130428433664
#
# In \[27\]:
#
#     pred_gb = pipeline_gb.predict(x_test)
#     # print(pred_gb)
#     gradient_boosting_mse = mean_squared_error(y_test, pred_gb)
#     gradient_boosting_rmse = mean_squared_error(y_test, pred_gb, squared=False)
#     gradient_boosting_r2_score = r2_score(y_test, pred_gb)
#
#     print("The Mean Squared Error using Gradient Boosting Regressor : {}".format(gradient_boosting_mse))
#     print("The Root Mean Squared Error using Gradient Boosting Regressor : {}".format(gradient_boosting_rmse))
#     print("The r2_sccore using Gradient Boosting Regressor : {}".format(gradient_boosting_r2_score))
#
#     The Mean Squared Error using Gradient Boosting Regressor : 126765008.11395901
#     The Root Mean Squared Error using Gradient Boosting Regressor : 11258.996763209367
#     The r2_sccore using Gradient Boosting Regressor : 0.7989076365417394
#
# In \[28\]:
#
#     age = df['Age'][495:742]
#     sns.scatterplot(age,pred_gb, hue=age)
#     plt.legend(loc="upper left")
#
# Out\[28\]:
#
#     <matplotlib.legend.Legend at 0x1d688af1cd0>
#
# ![](data:image/png;base64,...%0A)
#
# In \[29\]:
#
#     age = df['Age'][495:742]
#     diabetes = df['Diabetes'][495:742]
#     sns.scatterplot(age,pred_gb, hue=diabetes)
#
# Out\[29\]:
#
#     <matplotlib.axes._subplots.AxesSubplot at 0x1d68914f520>
#
# ![](data:image/png;base64,...%0A)
#
# In \[30\]:
#
#     weight = df['Weight'][:247]
#     height = df['Height'][:247]
#     sns.scatterplot(weight,height,hue=pred_gb)
#     plt.legend(loc="lower right")
#
# Out\[30\]:
#
#     <matplotlib.legend.Legend at 0x1d6891b29d0>
#
# ![](data:image/png;base64,...%0A)
#
# In \[31\]:
#
#     pred_gbm = pipeline_gbm.predict(x_test)
#     light_gbmr_mse = mean_squared_error(y_test, pred_gbm)
#     light_gbmr_rmse = mean_squared_error(y_test, pred_gbm, squared=False)
#     light_gbmr_r2_score = r2_score(y_test, pred_gbm)
#
#     # Evaluation Metrics
#     print("The Mean Squared Error using LGBMRegressor :{}".format(light_gbmr_mse))
#     print(('The Root Mean Squared Error using LGBMRegressor :{}'.format(light_gbmr_rmse)))
#     print(('The r2_score using LGBMRegressor :{}'.format(light_gbmr_r2_score)))
#
#     The Mean Squared Error using LGBMRegressor :101702412.47585735
#     The Root Mean Squared Error using LGBMRegressor :10084.761399054385
#     The r2_score using LGBMRegressor :0.838665426694159
#
# In \[32\]:
#
#     pred_xgb = pipeline_gbm.predict(x_test)
#     xgbr_mse = mean_squared_error(y_test, pred_xgb)
#     xgbr_rmse = mean_squared_error(y_test, pred_xgb, squared=False)
#     xgbr_r2_score = r2_score(y_test, pred_xgb)
#
#     # Evaluation Metrics
#     print("The Mean Squared Error using XGBRegressor :{}".format(xgbr_mse))
#     print(('The Root Mean Squared Error using XGBRegressor :{}'.format(xgbr_rmse)))
#     print(('The r2_score using XGBRegressor :{}'.format(xgbr_r2_score)))
#
#     The Mean Squared Error using XGBRegressor :101702412.47585735
#     The Root Mean Squared Error using XGBRegressor :10084.761399054385
#     The r2_score using XGBRegressor :0.838665426694159
#
# In \[33\]:
#
#     models = pd.DataFrame({
#         'Model' : ['Linear Regression', 'Decision Tree', 'Random Forest',
#                    'Gradient Boosting', 'KNN', 'Light GBMRegressor', 'XGBRegressor'],
#         'RMSE' : [linear_reg_rmse, decision_tree_rmse, random_forest_rmse,
#                 gradient_boosting_rmse, knn_rmse, light_gbmr_rmse, xgbr_rmse],
#         'r2_score' : [linear_reg_r2_score, decision_tree_r2_score, random_forest_r2_score,
#         gradient_boosting_r2_score, knn_r2_score, light_gbmr_r2_score, xgbr_r2_score]
#     })
#
#     models.sort_values(by='RMSE', ascending=True)
#
# Out\[33\]:
#
# |     | Model              | RMSE         | r2_score |
# |-----|--------------------|--------------|----------|
# | 2   | Random Forest      | 9704.166641  | 0.850613 |
# | 5   | Light GBMRegressor | 10084.761399 | 0.838665 |
# | 6   | XGBRegressor       | 10084.761399 | 0.838665 |
# | 3   | Gradient Boosting  | 11258.996763 | 0.798908 |
# | 1   | Decision Tree      | 13893.755333 | 0.693779 |
# | 0   | Linear Regression  | 15232.350298 | 0.631930 |
# | 4   | KNN                | 16960.781708 | 0.543661 |
#
# In \[34\]:
#
#     from sklearn.model_selection import train_test_split
#     from sklearn.ensemble import RandomForestRegressor
#
#     x1 = df.drop(['PremiumPrice'], axis=1)
#     y1 = df['PremiumPrice']
#     x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.25, random_state=10)
#
#     model = RandomForestRegressor()
#     model.fit(x_train,y_train)
#
# Out\[34\]:
#
#     RandomForestRegressor()
#
# In \[37\]:
#
#     def checkBoolean(value):
#         if(value == 0 or value == 1):
#             return True
#         return False
#
#     def checkNegative(value):
#         if(value >= 0):
#             return True
#         return False
#
#     flag = 1
#     while(1):
#         if(flag == 1):
#             age = int(input("Enter your Age "))
#             if(not checkNegative(age)):
#                 print("Age should be positive.")
#                 continue
#             flag += 1
#         if(flag == 2):
#             diabetes = int(input("Do you have Diabetes ?- Enter 1 if YES otherwise 0 "))
#             if(not checkBoolean(diabetes)):
#                 print("Diabetes value should be 0 or 1")
#                 continue
#             flag += 1
#         if(flag == 3):
#             bloodPressureProblems = int(input("Do you have any Blood Pressure Problems ?- Enter 1 if YES otherwise 0 "))
#             if(not checkBoolean(bloodPressureProblems)):
#                 print("Blood Pressure Problems value should be 0 or 1")
#                 continue
#             flag += 1
#         if(flag == 4):
#             anyTransplants = int(input("Do you went through any Transplants ?- Enter 1 if YES otherwise 0 "))
#             if(not checkBoolean(anyTransplants)):
#                 print("Any Transplants value should be 0 or 1")
#                 continue
#             flag += 1
#         if(flag == 5):
#             chronicDiseases = int(input("Do you have any Chronic Diseases ?- Enter 1 if YES otherwise 0 "))
#             if(not checkBoolean(chronicDiseases)):
#                 print("Chronic Diseases value should be 0 or 1")
#                 continue
#             flag += 1
#         if(flag == 6):
#             height = int(input("Enter your Height in cm "))
#             if(not checkNegative(height)):
#                 print("Height should be positive.")
#                 continue
#             flag += 1
#         if(flag == 7):
#             weight = int(input("Enter your Weight in kgs "))
#             if(not checkNegative(weight)):
#                 print("Weight should be positive.")
#                 continue
#             flag += 1
#         if(flag == 8):
#             allergies = int(input("Do you have any Allergies ?- Enter 1 if YES otherwise 0 "))
#             if(not checkBoolean(allergies)):
#                 print("Allergies value should be 0 or 1")
#                 continue
#             flag += 1
#         if(flag == 9):
#             historyOfCancer = int(input("Any of your ancestors suffered from cancer ?- Enter 1 if YES otherwise 0 "))
#             if(not checkBoolean(historyOfCancer)):
#                 print(" History Of Cancer in Family value should be 0 or 1")
#                 continue
#             flag += 1
#         if(flag == 10):
#             surgeries = int(input("Enter number of major surgeries happened to you "))
#             if(not checkNegative(surgeries)):
#                 print("Number of Surgeries should be positive.")
#                 continue
#             flag += 1
#         break
#
#     # [[45,0,0,0,0,155,57,0,0,0]]
#
#     features = np.array([[age,diabetes,bloodPressureProblems,anyTransplants,chronicDiseases,height,weight,allergies,historyOfCancer,surgeries]])
#     predicted = model.predict(features)
#     print(predicted)
#
#     Enter your Age 45
#     Do you have Diabetes ?- Enter 1 if YES otherwise 0 -7
#     Diabetes value should be 0 or 1
#     Do you have Diabetes ?- Enter 1 if YES otherwise 0 0
#     Do you have any Blood Pressure Problems ?- Enter 1 if YES otherwise 0 0
#     Do you went through any Transplants ?- Enter 1 if YES otherwise 0 0
#     Do you have any Chronic Diseases ?- Enter 1 if YES otherwise 0 0
#     Enter your Height in cm 155
#     Enter your Weight in kgs 57
#     Do you have any Allergies ?- Enter 1 if YES otherwise 0 0
#     Any of your ancestors suffered from cancer ?- Enter 1 if YES otherwise 0 0
#     Enter number of major surgeries happened to you 0
#     [99920.]
#
# In \[ \]:
